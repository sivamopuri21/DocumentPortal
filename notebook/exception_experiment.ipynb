# %%
1+1
# Out:
# 2

# %%
import sys
import traceback

# %%
from logger.custom_logger import CustomLogger
logger = CustomLogger().get_logger("exception_experiment")

# %%
class DocumentPoratalException(Exception):
    """Custome exception for DocumentPortal"""
    def __init__(self, error_message:str, error_details:sys):
        super().__init__(error_message)
        _,_,exc_tb = error_details.exc_info()
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.lineno = exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = " ".join(traceback.format_exception(*error_details.exc_info()))
    def __str__(self):
        return f""" 
            Error in [{self.file_name}] at line [{self.lineno}]
            Message: {self.error_message}
            Traceback: {self.traceback_str}
        """
    
if __name__ == "__main__":
    try:
        a=1/0
        print(a)
    except Exception as e:
        app_exc = DocumentPoratalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 19
#      18 try:
# ---> 19     a=1/0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPoratalException                  Traceback (most recent call last)
# Cell In[9], line 24
#      22 app_exc = DocumentPoratalException(e,sys)
#      23 logger.error(app_exc)
# ---> 24 raise app_exc
#
# DocumentPoratalException:
#             Error in [C:\Users\Sivakumar.Mopuri\AppData\Local\Temp\ipykernel_21696\2114819103.py] at line [19]
#             Message: division by zero
#             Traceback: Traceback (most recent call last):
#    File "C:\Users\Sivakumar.Mopuri\AppData\Local\Temp\ipykernel_21696\2114819103.py", line 19, in <module>
#     a=1/0
#  ZeroDivisionError: division by zero
